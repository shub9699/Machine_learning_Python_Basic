# %%
import numpy as np
import pandas as pd

# %%
#creating simple array
grades = np.array(['A','B','C','A','C'])

# %%
grades
# Out:
# array(['A', 'B', 'C', 'A', 'C'], dtype='<U1')

# %%
ser = pd.Series(grades)

# %%
ser
# Out:
# 0    A
# 1    B
# 2    C
# 3    A
# 4    C
# dtype: object

# %%
ser = pd.Series(grades,index=['Maths','Chem','Physics','Eng','Computer Sci'])

# %%
ser
# Out:
# Maths           A
# Chem            B
# Physics         C
# Eng             A
# Computer Sci    C
# dtype: object

# %%
ser.values
# Out:
# array(['A', 'B', 'C', 'A', 'C'], dtype=object)

# %%
ser.index
# Out:
# Index(['Maths', 'Chem', 'Physics', 'Eng', 'Computer Sci'], dtype='object')

# %%
ser['Maths']
# Out:
# 'A'

# %%
ser[0]
# Out:
# 'A'

# %%
#table ---> dataframe

# %%
l1 = ['A','B','C','A','C']

ser = pd.Series(l1)

# %%
ser
# Out:
# 0    A
# 1    B
# 2    C
# 3    A
# 4    C
# dtype: object

# %%
s1 = pd.Series(np.random.randint(1,5,100))
s2 = pd.Series(np.random.randint(1,4,100))
s3 = pd.Series(np.random.randint(10000,30000,100))

# %%
housmkt = pd.concat([s1,s2,s3],axis=1) #-->to do it horizontal

# %%
type(housmkt)
# Out:
# pandas.core.frame.DataFrame

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
housmkt.rename(columns = {0:'bedrooms',1:'bathrooms',2:'price_sq_meter'})
# Out:
#     bedrooms  bathrooms  price_sq_meter
# 0          1          2           24561
# 1          1          3           20912
# 2          1          3           18947
# 3          2          2           20225
# 4          3          3           13161
# ..       ...        ...             ...
# 95         4          3           25838
# 96         1          2           16457
# 97         4          2           17192
# 98         1          3           22870
# 99         2          3           27498
#
# [100 rows x 3 columns]

# %%
df = pd.read_csv('D:/Python/earthquake.csv')

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
df.shape
# Out:
# (23412, 21)

# %%
#check the null values
df.isnull()
# Out:
#         Date   Time  Latitude  Longitude   Type  Depth  Depth Error  \
# 0      False  False     False      False  False  False         True
# 1      False  False     False      False  False  False         True
# 2      False  False     False      False  False  False         True
# 3      False  False     False      False  False  False         True
# 4      False  False     False      False  False  False         True
# ...      ...    ...       ...        ...    ...    ...          ...
# 23407  False  False     False      False  False  False        False
# 23408  False  False     False      False  False  False        False
# 23409  False  False     False      False  False  False        False
# 23410  False  False     False      False  False  False        False
# 23411  False  False     False      False  False  False        False
#
#        Depth Seismic Stations  Magnitude  Magnitude Type  ...  \
# 0                        True      False           False  ...
# ...

# %%
df.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Latitude                          0
# Longitude                         0
# Type                              0
# Depth                             0
# Depth Error                   18951
# Depth Seismic Stations        16315
# Magnitude                         0
# Magnitude Type                    3
# Magnitude Error               23085
# Magnitude Seismic Stations    20848
# Azimuthal Gap                 16113
# Horizontal Distance           21808
# Horizontal Error              22256
# Root Mean Square               6060
# ID                                0
# Source                            0
# Location Source                   0
# Magnitude Source                  0
# Status                            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error',
#        'Depth Seismic Stations', 'Magnitude', 'Magnitude Type',
#        'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap',
#        'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID',
#        'Source', 'Location Source', 'Magnitude Source', 'Status'],
#       dtype='object')

# %%
df[['Date','Time','Latitude','Longitude']].head(15)
# Out:
#           Date      Time  Latitude  Longitude
# 0   01/02/1965  13:44:18    19.246    145.616
# 1   01/04/1965  11:29:49     1.863    127.352
# 2   01/05/1965  18:05:58   -20.579   -173.972
# 3   01/08/1965  18:49:43   -59.076    -23.557
# 4   01/09/1965  13:32:50    11.938    126.427
# 5   01/10/1965  13:36:32   -13.405    166.629
# 6   01/12/1965  13:32:25    27.357     87.867
# 7   01/15/1965  23:17:42   -13.309    166.212
# 8   01/16/1965  11:32:37   -56.452    -27.043
# 9   01/17/1965  10:43:17   -24.563    178.487
# 10  01/17/1965  20:57:41    -6.807    108.988
# 11  01/24/1965  00:11:17    -2.608    125.952
# 12  01/29/1965  09:35:30    54.636    161.703
# 13  02/01/1965  05:27:06   -18.697   -177.864
# 14  02/02/1965  15:56:51    37.523     73.251

# %%
#droping columns
df.drop(columns = 'Horizontal Error')
#this drops column temperoraly only fot this line
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# ...

# %%
#droping column permamntly
df.drop(columns = 'Horizontal Error',inplace=True)

# %%
#alternate command
del df['Horizontal Distance']

# %%
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# ...

# %%
#selecting single columns
df.Longitude
# Out:
# 0        145.6160
# 1        127.3520
# 2       -173.9720
# 3        -23.5570
# 4        126.4270
#            ...
# 23407   -118.8941
# 23408   -118.8957
# 23409    140.4262
# 23410    118.6639
# 23411    141.4103
# Name: Longitude, Length: 23412, dtype: float64

# %%
df['Depth Error']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 23407    1.2
# 23408    2.0
# 23409    1.8
# 23410    1.8
# 23411    2.2
# Name: Depth Error, Length: 23412, dtype: float64

# %%
df['Depth Error'].min()
# Out:
# 0.0

# %%
df['Depth Error'].max()
# Out:
# 91.295

# %%
df['Depth Error'].mode()
# Out:
# 0    1.8
# dtype: float64

# %%
df['Depth Error'].std()
# Out:
# 4.875183920072852

# %%
#imputing null values
df['Magnitude Error'].isnull().sum()
# Out:
# 23085

# %%
df['Magnitude Error'].fillna(df['Depth Error'].mode()[0],inplace=True)

# %%
#unique values for a column
df.Status.unique()
# Out:
# array(['Automatic', 'Reviewed'], dtype=object)

# %%
df.Status.nunique()
# Out:
# 2

# %%
df.Type.nunique()
# Out:
# 4

# %%
df.describe()
# Out:
#            Latitude     Longitude         Depth  Depth Error  \
# count  23412.000000  23412.000000  23412.000000  4461.000000
# mean       1.679033     39.639961     70.767911     4.993115
# std       30.113183    125.511959    122.651898     4.875184
# min      -77.080000   -179.997000     -1.100000     0.000000
# 25%      -18.653000    -76.349750     14.522500     1.800000
# 50%       -3.568500    103.982000     33.000000     3.500000
# 75%       26.190750    145.026250     54.000000     6.300000
# max       86.005000    179.998000    700.000000    91.295000
#
#        Depth Seismic Stations     Magnitude  Magnitude Error  \
# count             7097.000000  23412.000000       327.000000
# mean               275.364098      5.882531         0.071820
# std                162.141631      0.423066         0.051466
# min                  0.000000      5.500000         0.000000
# 25%                146.000000      5.600000         0.046000
# ...

# %%
df.shape
# Out:
# (23412, 19)

# %%
df[['Latitude','Longitude']].head(5)
# Out:
#    Latitude  Longitude
# 0    19.246    145.616
# 1     1.863    127.352
# 2   -20.579   -173.972
# 3   -59.076    -23.557
# 4    11.938    126.427

# %%
#by def it will sort in asc order
df[['Latitude','Longitude']].sort_values(by='Latitude')
# Out:
#        Latitude  Longitude
# 21304   -77.080   -148.864
# 11457   -72.448    174.838
# 18716   -67.034    111.199
# 4237    -66.448    -82.584
# 5717    -65.721   -175.714
# ...         ...        ...
# 14288    85.686     86.034
# 14255    85.734     84.439
# 14294    85.735     84.906
# 2910     85.992     30.825
# 15812    86.005     31.595
#
# [23412 rows x 2 columns]

# %%
df[['Latitude','Longitude']].sort_values(by='Latitude',ascending=False)
# Out:
#        Latitude  Longitude
# 15812    86.005     31.595
# 2910     85.992     30.825
# 14294    85.735     84.906
# 14255    85.734     84.439
# 14288    85.686     86.034
# ...         ...        ...
# 5717    -65.721   -175.714
# 4237    -66.448    -82.584
# 18716   -67.034    111.199
# 11457   -72.448    174.838
# 21304   -77.080   -148.864
#
# [23412 rows x 2 columns]

# %%
df.Type.unique()
# Out:
# array(['Earthquake', 'Nuclear Explosion', 'Explosion', 'Rock Burst'],
#       dtype=object)

# %%
df.Type.value_counts()
# Out:
# Earthquake           23232
# Nuclear Explosion      175
# Explosion                4
# Rock Burst               1
# Name: Type, dtype: int64

# %%
df.Type.value_counts(normalize=True)
# Out:
# Earthquake           0.992312
# Nuclear Explosion    0.007475
# Explosion            0.000171
# Rock Burst           0.000043
# Name: Type, dtype: float64

# %%
#how to filter a column
df[df.Type == 'Nuclear Explosion']
# Out:
#              Date      Time   Latitude   Longitude               Type  Depth  \
# 565    12/20/1966  15:30:01  37.302167 -116.408333  Nuclear Explosion    1.2
# 897    04/26/1968  15:00:02  37.295333 -116.455667  Nuclear Explosion    1.2
# 1129   12/19/1968  16:30:01  37.231500 -116.473667  Nuclear Explosion    1.4
# 1380   09/16/1969  14:30:01  37.314167 -116.460667  Nuclear Explosion    1.2
# 1532   03/26/1970  19:00:01  37.300500 -116.534167  Nuclear Explosion    1.2
# ...           ...       ...        ...         ...                ...    ...
# 11963  06/10/1994  06:25:58  41.527000   88.710000  Nuclear Explosion    0.0
# 12142  10/07/1994  03:25:58  41.662000   88.753000  Nuclear Explosion    0.0
# 12450  05/15/1995  04:05:58  41.603000   88.820000  Nuclear Explosion    0.0
# 12613  08/17/1995  00:59:58  41.559000   88.800000  Nuclear Explosion    0.0
# 13054  06/08/1996  02:55:58  41.657000   88.690000  Nuclear Explosion    0.0
#
# ...

# %%
#apply multiple filters
df[(df.Type == 'Nuclear Explosion') | (df.Type == 'Explosion')]
# Out:
#              Date      Time   Latitude   Longitude               Type  Depth  \
# 565    12/20/1966  15:30:01  37.302167 -116.408333  Nuclear Explosion    1.2
# 897    04/26/1968  15:00:02  37.295333 -116.455667  Nuclear Explosion    1.2
# 1129   12/19/1968  16:30:01  37.231500 -116.473667  Nuclear Explosion    1.4
# 1380   09/16/1969  14:30:01  37.314167 -116.460667  Nuclear Explosion    1.2
# 1532   03/26/1970  19:00:01  37.300500 -116.534167  Nuclear Explosion    1.2
# ...           ...       ...        ...         ...                ...    ...
# 11963  06/10/1994  06:25:58  41.527000   88.710000  Nuclear Explosion    0.0
# 12142  10/07/1994  03:25:58  41.662000   88.753000  Nuclear Explosion    0.0
# 12450  05/15/1995  04:05:58  41.603000   88.820000  Nuclear Explosion    0.0
# 12613  08/17/1995  00:59:58  41.559000   88.800000  Nuclear Explosion    0.0
# 13054  06/08/1996  02:55:58  41.657000   88.690000  Nuclear Explosion    0.0
#
# ...

# %%
df[(df.Type == 'Nuclear Explosion') | (df.Type == 'Explosion')].shape
# Out:
# (179, 19)

# %%
df[(df.Type == 'Nuclear Explosion') | (df.Type == 'Explosion')][df.Magnitude > 6]
# Out:
# C:\Users\Shubham\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#              Date      Time  Latitude  Longitude               Type  Depth  \
# 2797   07/23/1973  01:22:58    49.986     78.853  Nuclear Explosion    0.0
# 2859   09/12/1973  06:59:54    73.302     55.161  Nuclear Explosion    0.0
# 2897   10/27/1973  06:59:57    70.779     54.177  Nuclear Explosion    0.0
# 3218   08/29/1974  09:59:55    73.366     55.094  Nuclear Explosion    0.0
# 3286   11/02/1974  04:59:57    70.817     54.063  Nuclear Explosion    0.0
# 3593   08/23/1975  08:59:58    73.369     54.641          Explosion    0.0
# 3661   10/18/1975  08:59:56    70.843     53.690  Nuclear Explosion    0.0
# 3663   10/21/1975  11:59:57    73.351     55.078  Nuclear Explosion    0.0
# 5198   06/23/1979  02:56:58    49.918     78.915  Nuclear Explosion    0.0
# ...

# %%
df[(df.Type == 'Nuclear Explosion') | (df.Type == 'Explosion')][df.Magnitude > 6].shape
# Out:
# C:\Users\Shubham\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# (35, 19)

# %%
bigearthquakes = df[(df.Type == 'Nuclear Explosion') | (df.Type == 'Explosion')][df.Magnitude > 6]
# Out:
# C:\Users\Shubham\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
bigearthquakes.head()
# Out:
#             Date      Time  Latitude  Longitude               Type  Depth  \
# 2797  07/23/1973  01:22:58    49.986     78.853  Nuclear Explosion    0.0
# 2859  09/12/1973  06:59:54    73.302     55.161  Nuclear Explosion    0.0
# 2897  10/27/1973  06:59:57    70.779     54.177  Nuclear Explosion    0.0
# 3218  08/29/1974  09:59:55    73.366     55.094  Nuclear Explosion    0.0
# 3286  11/02/1974  04:59:57    70.817     54.063  Nuclear Explosion    0.0
#
#       Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 2797          NaN                     NaN        6.3             MB
# 2859          NaN                     NaN        6.8             MB
# 2897          NaN                     NaN        6.9             MB
# 3218          NaN                     NaN        6.4             MB
# 3286          NaN                     NaN        6.7             MB
#
#       Magnitude Error  Magnitude Seismic Stations  Azimuthal Gap  \
# ...

# %%
bigearthquakes = bigearthquakes.reset_index(drop=True)

# %%
#dataframe_name.iloc[row start:row end,column start: column end]
bigearthquakes.iloc[:5,:5]
# Out:
#          Date      Time  Latitude  Longitude               Type
# 0  07/23/1973  01:22:58    49.986     78.853  Nuclear Explosion
# 1  09/12/1973  06:59:54    73.302     55.161  Nuclear Explosion
# 2  10/27/1973  06:59:57    70.779     54.177  Nuclear Explosion
# 3  08/29/1974  09:59:55    73.366     55.094  Nuclear Explosion
# 4  11/02/1974  04:59:57    70.817     54.063  Nuclear Explosion

# %%
bigearthquakes.iloc[:,:5]
# Out:
#           Date      Time  Latitude  Longitude               Type
# 0   07/23/1973  01:22:58    49.986     78.853  Nuclear Explosion
# 1   09/12/1973  06:59:54    73.302     55.161  Nuclear Explosion
# 2   10/27/1973  06:59:57    70.779     54.177  Nuclear Explosion
# 3   08/29/1974  09:59:55    73.366     55.094  Nuclear Explosion
# 4   11/02/1974  04:59:57    70.817     54.063  Nuclear Explosion
# 5   08/23/1975  08:59:58    73.369     54.641          Explosion
# 6   10/18/1975  08:59:56    70.843     53.690  Nuclear Explosion
# 7   10/21/1975  11:59:57    73.351     55.078  Nuclear Explosion
# 8   06/23/1979  02:56:58    49.918     78.915  Nuclear Explosion
# 9   08/04/1979  03:56:57    49.901     78.959  Nuclear Explosion
# 10  08/18/1979  02:51:57    49.971     79.010  Nuclear Explosion
# 11  12/23/1979  04:56:58    49.964     78.827  Nuclear Explosion
# 12  09/14/1980  02:42:39    49.976     78.889  Nuclear Explosion
# ...

# %%
bigearthquakes.loc[[13]]
# Out:
#           Date      Time  Latitude  Longitude               Type  Depth  \
# 13  12/27/1981  03:43:14    49.909     78.873  Nuclear Explosion    0.0
#
#     Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 13          NaN                     NaN        6.2             MB
#
#     Magnitude Error  Magnitude Seismic Stations  Azimuthal Gap  \
# 13              1.8                        96.0            NaN
#
#     Root Mean Square          ID Source Location Source Magnitude Source  \
# 13               1.0  USP0001HPJ     US              US               US
#
#       Status
# 13  Reviewed

# %%
bigearthquakes.loc[[13],'Type']
# Out:
# 13    Nuclear Explosion
# Name: Type, dtype: object

# %%
bigearthquakes.loc[[13],'Type'] = 'Volcanic Eruption'

# %%
bigearthquakes.loc[[13]]
# Out:
#           Date      Time  Latitude  Longitude               Type  Depth  \
# 13  12/27/1981  03:43:14    49.909     78.873  Volcanic Eruption    0.0
#
#     Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 13          NaN                     NaN        6.2             MB
#
#     Magnitude Error  Magnitude Seismic Stations  Azimuthal Gap  \
# 13              1.8                        96.0            NaN
#
#     Root Mean Square          ID Source Location Source Magnitude Source  \
# 13               1.0  USP0001HPJ     US              US               US
#
#       Status
# 13  Reviewed

# %%
#how to create a new column

# %%
bigearthquakes['new col 1'] = bigearthquakes.Longitude - bigearthquakes.Latitude

# %%
bigearthquakes[['Longitude','Latitude','new col 1']]
# Out:
#     Longitude  Latitude  new col 1
# 0      78.853    49.986     28.867
# 1      55.161    73.302    -18.141
# 2      54.177    70.779    -16.602
# 3      55.094    73.366    -18.272
# 4      54.063    70.817    -16.754
# 5      54.641    73.369    -18.728
# 6      53.690    70.843    -17.153
# 7      55.078    73.351    -18.273
# 8      78.915    49.918     28.997
# 9      78.959    49.901     29.058
# 10     79.010    49.971     29.039
# 11     78.827    49.964     28.863
# 12     78.889    49.976     28.913
# 13     78.873    49.909     28.964
# 14     78.931    49.889     29.042
# 15     78.856    49.995     28.861
# 16     78.869    49.928     28.941
# 17     78.981    49.906     29.075
# 18     78.907    49.921     28.986
# 19     78.963    49.891     29.072
# 20     78.834    49.949     28.885
# 21     78.862    49.957     28.905
# 22     78.829    49.928     28.901
# 23     88.737    41.584     47.153
# 24     78.735    49.913     28.822
# 25     78.844    49.989     28.855
# ...

# %%
bigearthquakes['new col 2'] =  'scaler value'

# %%
bigearthquakes
# Out:
#           Date      Time  Latitude  Longitude               Type  Depth  \
# 0   07/23/1973  01:22:58    49.986     78.853  Nuclear Explosion    0.0
# 1   09/12/1973  06:59:54    73.302     55.161  Nuclear Explosion    0.0
# 2   10/27/1973  06:59:57    70.779     54.177  Nuclear Explosion    0.0
# 3   08/29/1974  09:59:55    73.366     55.094  Nuclear Explosion    0.0
# 4   11/02/1974  04:59:57    70.817     54.063  Nuclear Explosion    0.0
# 5   08/23/1975  08:59:58    73.369     54.641          Explosion    0.0
# 6   10/18/1975  08:59:56    70.843     53.690  Nuclear Explosion    0.0
# 7   10/21/1975  11:59:57    73.351     55.078  Nuclear Explosion    0.0
# 8   06/23/1979  02:56:58    49.918     78.915  Nuclear Explosion    0.0
# 9   08/04/1979  03:56:57    49.901     78.959  Nuclear Explosion    0.0
# 10  08/18/1979  02:51:57    49.971     79.010  Nuclear Explosion    0.0
# 11  12/23/1979  04:56:58    49.964     78.827  Nuclear Explosion    0.0
# ...

# %%
df[df['Type']=='Earthquake']['Magnitude']
# Out:
# 0        6.0
# 1        5.8
# 2        6.2
# 3        5.8
# 4        5.8
#         ...
# 23407    5.6
# 23408    5.5
# 23409    5.9
# 23410    6.3
# 23411    5.5
# Name: Magnitude, Length: 23232, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df[df['Type']=='Earthquake']['Magnitude'],bins=40, color='green')
plt.xlabel('Magnitude',size=10)
plt.ylabel('Number of earthquakes',size=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#how to create an empty df
e1 = pd.DataFrame()

# %%
e1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
e1 = df[df['Type']=='Earthquake']

# %%
e1['DateTime'] = pd.to_datetime(e1.Date,utc=True)
# Out:
# C:\Users\Shubham\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
e1['DateTime']
# Out:
# 0       1965-01-02 00:00:00+00:00
# 1       1965-01-04 00:00:00+00:00
# 2       1965-01-05 00:00:00+00:00
# 3       1965-01-08 00:00:00+00:00
# 4       1965-01-09 00:00:00+00:00
#                    ...
# 23407   2016-12-28 00:00:00+00:00
# 23408   2016-12-28 00:00:00+00:00
# 23409   2016-12-28 00:00:00+00:00
# 23410   2016-12-29 00:00:00+00:00
# 23411   2016-12-30 00:00:00+00:00
# Name: DateTime, Length: 23232, dtype: datetime64[ns, UTC]

# %%
e1['DateTime'].dt.year
# Out:
# 0        1965
# 1        1965
# 2        1965
# 3        1965
# 4        1965
#          ...
# 23407    2016
# 23408    2016
# 23409    2016
# 23410    2016
# 23411    2016
# Name: DateTime, Length: 23232, dtype: int64

# %%
e1['DateTime'].dt.month
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 23407    12
# 23408    12
# 23409    12
# 23410    12
# 23411    12
# Name: DateTime, Length: 23232, dtype: int64

# %%
e1['DateTime'].dt.week
# Out:
# 0        53
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 23407    52
# 23408    52
# 23409    52
# 23410    52
# 23411    52
# Name: DateTime, Length: 23232, dtype: int64

# %%
#identify which year has most of the earthquakes
plt.figure(figsize=(12,8))
e1['DateTime'].dt.year.value_counts().sort_index().plot(kind='bar')
plt.title('count of earthquakes by year')
# Out:
# Text(0.5, 1.0, 'count of earthquakes by year')
